# %%
import pandas as pd
data = pd.read_csv('titanic/train.csv') # Comma Separated Values - Valores Separados Por Vírgula
data.columns = ['IdPassageiro', 'Sobreviveu', 'Classe', 'Nome', 'Sexo', 'Idade', 
                'IrmaoConjuge', 'PaisFilhos', 'Bilhete', 'Tarifa', 'Cabine', 'Embarque']
data.head()
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris    male   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                             Heikkinen, Miss. Laina  female   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                           Allen, Mr. William Henry    male   35.0
#
#    IrmaoConjuge  PaisFilhos           Bilhete   Tarifa Cabine Embarque
# 0             1           0         A/5 21171   7.2500    NaN        S
# 1             1           0          PC 17599  71.2833    C85        C
# 2             0           0  STON/O2. 3101282   7.9250    NaN        S
# ...

# %%
data['Sexo'].str.replace('le', 'LA')
data['Sexo'].replace('le', 'LA', regex=True)
# Out:
# 0        maLA
# 1      femaLA
# 2      femaLA
# 3      femaLA
# 4        maLA
#         ...
# 886      maLA
# 887    femaLA
# 888    femaLA
# 889      maLA
# 890      maLA
# Name: Sexo, Length: 891, dtype: object

# %%
data['Sexo'].map({'male': 'homem', 'female': 'mulher'})
# Out:
# 0       homem
# 1      mulher
# 2      mulher
# 3      mulher
# 4       homem
#         ...
# 886     homem
# 887    mulher
# 888    mulher
# 889     homem
# 890     homem
# Name: Sexo, Length: 891, dtype: object

# %%
data['Sexo'].replace({'male': 'homem', 'female': 'mulher'}, inplace=True)

# %%
data['Sexo'].replace({'homem': 'male', 'mulher': 'female'}, inplace=True)

# %%
#data['Sexo'] = data['Sexo'].map({'male': 'homem', 'female': 'mulher'})
data
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 0               1           0       3
# 1               2           1       1
# 2               3           1       3
# 3               4           1       1
# 4               5           0       3
# ..            ...         ...     ...
# 886           887           0       2
# 887           888           1       1
# 888           889           0       3
# 889           890           1       1
# 890           891           0       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris   homem   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
# 2                               Heikkinen, Miss. Laina  mulher   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher   35.0
# 4                             Allen, Mr. William Henry   homem   35.0
# ..                                                 ...     ...    ...
# ...

# %%
data['Sexo'].value_counts()
# Out:
# Series([], Name: Sexo, dtype: int64)

# %%
data['Sexo'].replace(['male','female'],'pessoas')
# Out:
# 0      pessoas
# 1      pessoas
# 2      pessoas
# 3      pessoas
# 4      pessoas
#         ...
# 886    pessoas
# 887    pessoas
# 888    pessoas
# 889    pessoas
# 890    pessoas
# Name: Sexo, Length: 891, dtype: object

# %%
df = data.copy()

# %%
df['Classe'].replace(1, method = 'bfill')
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 886    2
# 887    3
# 888    3
# 889    3
# 890    3
# Name: Classe, Length: 891, dtype: int64

# %%
df['Classe'].replace(2, method = 'ffill', limit = 4)
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    3
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Classe, Length: 891, dtype: int64

# %%
data['Classe'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
data.groupby('Classe').mean()
# Out:
#         IdPassageiro  Sobreviveu      Idade  IrmaoConjuge  PaisFilhos  \
# Classe
# 1         461.597222    0.629630  38.233441      0.416667    0.356481
# 2         445.956522    0.472826  29.877630      0.402174    0.380435
# 3         439.154786    0.242363  25.140620      0.615071    0.393075
#
#            Tarifa
# Classe
# 1       84.154687
# 2       20.662183
# 3       13.675550

# %%
data = data.loc[data['Sobreviveu'] ==1]
data.groupby(['Classe', 'Sexo']).mean()
# Out:
#                IdPassageiro  Sobreviveu      Idade  IrmaoConjuge  PaisFilhos  \
# Classe Sexo
# 1      female    473.967033         1.0  34.939024      0.549451    0.428571
#        male      527.777778         1.0  36.248000      0.377778    0.311111
# 2      female    444.785714         1.0  28.080882      0.485714    0.642857
#        male      415.588235         1.0  16.022000      0.529412    0.647059
# 3      female    359.083333         1.0  19.329787      0.500000    0.500000
#        male      447.638298         1.0  22.274211      0.340426    0.297872
#
#                    Tarifa
# Classe Sexo
# 1      female  105.978159
#        male     74.637320
# 2      female   22.288989
#        male     21.095100
# 3      female   12.464526
#        male     15.579696

# %%
data
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 0               1           0       3
# 1               2           1       1
# 2               3           1       3
# 3               4           1       1
# 4               5           0       3
# ..            ...         ...     ...
# 886           887           0       2
# 887           888           1       1
# 888           889           0       3
# 889           890           1       1
# 890           891           0       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris   homem   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
# 2                               Heikkinen, Miss. Laina  mulher   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher   35.0
# 4                             Allen, Mr. William Henry   homem   35.0
# ..                                                 ...     ...    ...
# ...

# %% [markdown]
# ### Groupby

# %%
display(data.groupby('Sexo').sum())
display(data.groupby('Sexo').mean())
# Out:
#         IdPassageiro  Sobreviveu  Classe     Idade  IrmaoConjuge  PaisFilhos  \
# Sexo
# homem         262043         109    1379  13919.17           248         136
# mulher        135343         233     678   7286.00           218         204
#
#             Tarifa
# Sexo
# homem   14727.2865
# mulher  13966.6628
#         IdPassageiro  Sobreviveu    Classe      Idade  IrmaoConjuge  \
# Sexo
# homem     454.147314    0.188908  2.389948  30.726645      0.429809
# mulher    431.028662    0.742038  2.159236  27.915709      0.694268
#
#         PaisFilhos     Tarifa
# Sexo
# homem     0.235702  25.523893
# mulher    0.649682  44.479818

# %%
data.groupby(['Sexo','Classe', 'Sobreviveu']).mean()
# Out:
#                           IdPassageiro      Idade  IrmaoConjuge  PaisFilhos  \
# Sexo   Classe Sobreviveu
# homem  1      0             413.623377  44.581967      0.272727    0.259740
#               1             527.777778  36.248000      0.377778    0.311111
#        2      0             454.010989  33.369048      0.307692    0.142857
#               1             415.588235  16.022000      0.529412    0.647059
#        3      0             456.750000  27.255814      0.523333    0.213333
#               1             447.638298  22.274211      0.340426    0.297872
# mulher 1      0             325.000000  25.666667      0.666667    1.333333
#               1             473.967033  34.939024      0.549451    0.428571
#        2      0             423.500000  36.000000      0.500000    0.166667
#               1             444.785714  28.080882      0.485714    0.642857
#        3      0             440.375000  23.818182      1.291667    1.097222
# ...

# %%
data[data['Sobreviveu'] == 1].groupby(['Sexo','Classe']).max()
# Out:
# C:\Users\LETICI~1.LOP\AppData\Local\Temp/ipykernel_51524/3534871452.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   data[data['Sobreviveu'] == 1].groupby(['Sexo','Classe']).max()
#                IdPassageiro  Sobreviveu  \
# Sexo   Classe
# homem  1                890           1
#        2                832           1
#        3                870           1
# mulher 1                888           1
#        2                881           1
#        3                876           1
#
#                                                        Nome  Idade  \
# Sexo   Classe
# homem  1                                  Woolner, Mr. Hugh   80.0
#        2                       Williams, Mr. Charles Eugene   62.0
#        3                            de Mulder, Mr. Theodore   45.0
# ...

# %%
# obter a maior idade por Sexo e Classe dos sobreviventes
data[data['Sobreviveu'] == 1].groupby(['Sexo','Classe']).apply(lambda data: data.loc[data.Idade.idxmax()])
# Out:
#                IdPassageiro  Sobreviveu  Classe  \
# Sexo   Classe
# homem  1                631           1       1
#        2                571           1       2
#        3                339           1       3
# mulher 1                276           1       1
#        2                 16           1       2
#        3                484           1       3
#
#                                                Nome    Sexo  Idade  \
# Sexo   Classe
# homem  1       Barkworth, Mr. Algernon Henry Wilson   homem   80.0
#        2                         Harris, Mr. George   homem   62.0
#        3                      Dahl, Mr. Karl Edwart   homem   45.0
# mulher 1          Andrews, Miss. Kornelia Theodosia  mulher   63.0
#        2           Hewlett, Mrs. (Mary D Kingcome)   mulher   55.0
#        3                     Turkula, Mrs. (Hedwig)  mulher   63.0
#
#                IrmaoConjuge  PaisFilhos      Bilhete   Tarifa Cabine Embarque
# Sexo   Classe
# ...

# %%
data[data['Sobreviveu'] == 1].groupby(['Sexo','Classe'], as_index = False ).mean()
# Out:
#      Sexo  Classe  IdPassageiro  Sobreviveu      Idade  IrmaoConjuge  \
# 0   homem       1    527.777778         1.0  36.248000      0.377778
# 1   homem       2    415.588235         1.0  16.022000      0.529412
# 2   homem       3    447.638298         1.0  22.274211      0.340426
# 3  mulher       1    473.967033         1.0  34.939024      0.549451
# 4  mulher       2    444.785714         1.0  28.080882      0.485714
# 5  mulher       3    359.083333         1.0  19.329787      0.500000
#
#    PaisFilhos      Tarifa
# 0    0.311111   74.637320
# 1    0.647059   21.095100
# 2    0.297872   15.579696
# 3    0.428571  105.978159
# 4    0.642857   22.288989
# 5    0.500000   12.464526

# %%
data[data['Sobreviveu'] == 1].groupby(['Sexo','Classe']).mean().reset_index()
# Out:
#      Sexo  Classe  IdPassageiro  Sobreviveu      Idade  IrmaoConjuge  \
# 0   homem       1    527.777778         1.0  36.248000      0.377778
# 1   homem       2    415.588235         1.0  16.022000      0.529412
# 2   homem       3    447.638298         1.0  22.274211      0.340426
# 3  mulher       1    473.967033         1.0  34.939024      0.549451
# 4  mulher       2    444.785714         1.0  28.080882      0.485714
# 5  mulher       3    359.083333         1.0  19.329787      0.500000
#
#    PaisFilhos      Tarifa
# 0    0.311111   74.637320
# 1    0.647059   21.095100
# 2    0.297872   15.579696
# 3    0.428571  105.978159
# 4    0.642857   22.288989
# 5    0.500000   12.464526

# %%
data[data['Sobreviveu'] == 1].groupby(['Sexo','Classe']).agg({'Idade': 'mean', 'PaisFilhos': 'sum'})
# Out:
#                    Idade  PaisFilhos
# Sexo   Classe
# homem  1       36.248000          14
#        2       16.022000          11
#        3       22.274211          14
# mulher 1       34.939024          39
#        2       28.080882          45
#        3       19.329787          36

# %%
# obter várias funções da idade dos sobreviventes
data[data['Sobreviveu'] == 1].groupby(['Classe']).Idade.agg([min, max])
# Out:
#          min   max
# Classe
# 1       0.92  80.0
# 2       0.67  62.0
# 3       0.42  63.0

# %%
data
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 0               1           0       3
# 1               2           1       1
# 2               3           1       3
# 3               4           1       1
# 4               5           0       3
# ..            ...         ...     ...
# 886           887           0       2
# 887           888           1       1
# 888           889           0       3
# 889           890           1       1
# 890           891           0       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris   homem   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
# 2                               Heikkinen, Miss. Laina  mulher   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher   35.0
# 4                             Allen, Mr. William Henry   homem   35.0
# ..                                                 ...     ...    ...
# ...

# %%
# ascending para ordens descrescente
data['Sexo'].value_counts(ascending=True)
# Out:
# mulher    314
# homem     577
# Name: Sexo, dtype: int64

# %%
# ignore_index = atribuindo um índice padrão. 
data.sort_values('Classe', ascending=False, inplace=True, ignore_index=True)
display(data)
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 0               1           0       3
# 1             512           0       3
# 2             501           0       3
# 3             502           0       3
# 4             503           0       3
# ..            ...         ...     ...
# 886           103           0       1
# 887           711           1       1
# 888           712           0       1
# 889           713           1       1
# 890           446           1       1
#
#                                                  Nome    Sexo  Idade  \
# 0                             Braund, Mr. Owen Harris    male   22.0
# 1                                   Webber, Mr. James    male    NaN
# 2                                    Calic, Mr. Petar    male   17.0
# 3                                 Canavan, Miss. Mary  female   21.0
# 4                      O'Sullivan, Miss. Bridget Mary  female    NaN
# ..                                                ...     ...    ...
# ...

# %%
data.sort_values('Embarque', ascending=False, ignore_index=True)
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 0               1           0       3
# 1             555           1       3
# 2             541           1       1
# 3             542           0       3
# 4             543           0       3
# ..            ...         ...     ...
# 886            97           0       1
# 887           545           0       1
# 888           382           1       3
# 889            62           1       1
# 890           830           1       1
#
#                                           Nome    Sexo  Idade  IrmaoConjuge  \
# 0                      Braund, Mr. Owen Harris    male   22.0             1
# 1                           Ohman, Miss. Velin  female   22.0             0
# 2                      Crosby, Miss. Harriet R  female   36.0             0
# 3         Andersson, Miss. Ingeborg Constanzia  female    9.0             4
# 4            Andersson, Miss. Sigrid Elisabeth  female   11.0             4
# ...

# %%
data.sort_values('Embarque', ascending=False, ignore_index=True, na_position='first')
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 0              62           1       1
# 1             830           1       1
# 2               1           0       3
# 3             555           1       3
# 4             541           1       1
# ..            ...         ...     ...
# 886           256           1       3
# 887            98           1       1
# 888            97           0       1
# 889           545           0       1
# 890           382           1       3
#
#                                           Nome    Sexo  Idade  IrmaoConjuge  \
# 0                          Icard, Miss. Amelie  female   38.0             0
# 1    Stone, Mrs. George Nelson (Martha Evelyn)  female   62.0             0
# 2                      Braund, Mr. Owen Harris    male   22.0             1
# 3                           Ohman, Miss. Velin  female   22.0             0
# 4                      Crosby, Miss. Harriet R  female   36.0             0
# ...

# %%
data
# Out:
#      IdPassageiro  Sobreviveu  Classe                               Nome  \
# 711           264           0       1              Harrison, Mr. William
# 739           823           0       1    Reuchlin, Jonkheer. John George
# 745           807           0       1             Andrews, Mr. Thomas Jr
# 755           816           0       1                   Fry, Mr. Richard
# 770           634           0       1      Parr, Mr. William Henry Marsh
# ..            ...         ...     ...                                ...
# 199           864           0       3  Sage, Miss. Dorothy Edith "Dolly"
# 229           847           0       3           Sage, Mr. Douglas Bullen
# 377           181           0       3       Sage, Miss. Constance Gladys
# 380           160           0       3         Sage, Master. Thomas Henry
# 404           202           0       3                Sage, Mr. Frederick
#
#        Sexo  Idade  IrmaoConjuge  PaisFilhos   Bilhete  Tarifa Cabine Embarque
# ...

# %%
data.describe().sort_values('mean', axis=1)
# Out:
#        IrmaoConjuge  PaisFilhos  Sobreviveu      Classe       Idade  \
# count    183.000000  183.000000  183.000000  183.000000  183.000000
# mean       0.464481    0.475410    0.672131    1.191257   35.674426
# std        0.644159    0.754617    0.470725    0.515187   15.643866
# min        0.000000    0.000000    0.000000    1.000000    0.920000
# 25%        0.000000    0.000000    0.000000    1.000000   24.000000
# 50%        0.000000    0.000000    1.000000    1.000000   36.000000
# 75%        1.000000    1.000000    1.000000    1.000000   47.500000
# max        3.000000    4.000000    1.000000    3.000000   80.000000
#
#            Tarifa  IdPassageiro
# count  183.000000    183.000000
# mean    78.682469    455.366120
# std     76.347843    247.052476
# min      0.000000      2.000000
# 25%     29.700000    263.500000
# 50%     57.000000    457.000000
# 75%     90.000000    676.000000
# max    512.329200    890.000000

# %%
# transformando as colunas em índices e vice versa
data.describe().T
# Out:
#               count        mean         std   min    25%    50%    75%  \
# IdPassageiro  183.0  455.366120  247.052476  2.00  263.5  457.0  676.0
# Sobreviveu    183.0    0.672131    0.470725  0.00    0.0    1.0    1.0
# Classe        183.0    1.191257    0.515187  1.00    1.0    1.0    1.0
# Idade         183.0   35.674426   15.643866  0.92   24.0   36.0   47.5
# IrmaoConjuge  183.0    0.464481    0.644159  0.00    0.0    0.0    1.0
# PaisFilhos    183.0    0.475410    0.754617  0.00    0.0    0.0    1.0
# Tarifa        183.0   78.682469   76.347843  0.00   29.7   57.0   90.0
#
#                    max
# IdPassageiro  890.0000
# Sobreviveu      1.0000
# Classe          3.0000
# Idade          80.0000
# IrmaoConjuge    3.0000
# PaisFilhos      4.0000
# Tarifa        512.3292

# %%
data.describe()
# Out:
#        IdPassageiro  Sobreviveu      Classe       Idade  IrmaoConjuge  \
# count    183.000000  183.000000  183.000000  183.000000    183.000000
# mean     455.366120    0.672131    1.191257   35.674426      0.464481
# std      247.052476    0.470725    0.515187   15.643866      0.644159
# min        2.000000    0.000000    1.000000    0.920000      0.000000
# 25%      263.500000    0.000000    1.000000   24.000000      0.000000
# 50%      457.000000    1.000000    1.000000   36.000000      0.000000
# 75%      676.000000    1.000000    1.000000   47.500000      1.000000
# max      890.000000    1.000000    3.000000   80.000000      3.000000
#
#        PaisFilhos      Tarifa
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
data['Embarque'].value_counts(dropna=False)
# Out:
# S    116
# C     65
# Q      2
# Name: Embarque, dtype: int64

# %%
data.sort_values('Classe', ascending=False, inplace=True, ignore_index=True)
display(data)
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 0               1           0       3
# 1             512           0       3
# 2             501           0       3
# 3             502           0       3
# 4             503           0       3
# ..            ...         ...     ...
# 886           103           0       1
# 887           711           1       1
# 888           712           0       1
# 889           713           1       1
# 890           446           1       1
#
#                                                  Nome    Sexo  Idade  \
# 0                             Braund, Mr. Owen Harris    male   22.0
# 1                                   Webber, Mr. James    male    NaN
# 2                                    Calic, Mr. Petar    male   17.0
# 3                                 Canavan, Miss. Mary  female   21.0
# 4                      O'Sullivan, Miss. Bridget Mary  female    NaN
# ..                                                ...     ...    ...
# ...

# %%
display(data)
data = data.sort_index(ascending=False)
display(data)
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 0               1           0       3
# 1               2           1       1
# 2               3           1       3
# 3               4           1       1
# 4               5           0       3
# ..            ...         ...     ...
# 886           887           0       2
# 887           888           1       1
# 888           889           0       3
# 889           890           1       1
# 890           891           0       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris    male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                               Heikkinen, Miss. Laina  female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                             Allen, Mr. William Henry    male   35.0
# ..                                                 ...     ...    ...
# ...

# %%
#create a dataframe
df_1 = pd.DataFrame(
    [['Arjun', 70, 86],
     ['Kiku', 80, 76],
	 ['Mama', 99, 99],
     ['Lini', 79, 92]],
    index = [2, 1, 6, 5],
    columns=['name', 'aptitude', 'cooking'])

print(df_1)

#sort dataframe by index in ascending order
df_1 = df_1.sort_index(ascending=True)

print('\nDataFrame after sorting by index\n')
print(df_1)
# Out:
#     name  aptitude  cooking
# 2  Arjun        70       86
# 1   Kiku        80       76
# 6   Mama        99       99
# 5   Lini        79       92
#
# DataFrame after sorting by index
#
#     name  aptitude  cooking
# 1   Kiku        80       76
# 2  Arjun        70       86
# 5   Lini        79       92
# 6   Mama        99       99
