# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('titanic/train.csv') # Comma Separated Values - Valores Separados Por Vírgula
data.columns = ['IdPassageiro', 'Sobreviveu', 'Classe', 'Nome', 'Sexo', 'Idade', 
                'IrmaoConjuge', 'PaisFilhos', 'Bilhete', 'Tarifa', 'Cabine', 'Embarque']
data['Sexo'].replace({'male': 'homem', 'female': 'mulher'}, inplace=True)
data.head()
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris   homem   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
# 2                             Heikkinen, Miss. Laina  mulher   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher   35.0
# 4                           Allen, Mr. William Henry   homem   35.0
#
#    IrmaoConjuge  PaisFilhos           Bilhete   Tarifa Cabine Embarque
# 0             1           0         A/5 21171   7.2500    NaN        S
# 1             1           0          PC 17599  71.2833    C85        C
# 2             0           0  STON/O2. 3101282   7.9250    NaN        S
# 3             1           0            113803  53.1000   C123        S
# 4             0           0            373450   8.0500    NaN        S

# %%
pd.crosstab(data['Sobreviveu'], data['Classe'] )
# Out:
# Classe        1   2    3
# Sobreviveu
# 0            80  97  372
# 1           136  87  119

# %%
pd.crosstab(data['Sobreviveu'], data['Classe'], values = data['Idade'], aggfunc = "mean", margins=True)
# Out:
# Classe              1          2          3        All
# Sobreviveu
# 0           43.695312  33.544444  26.555556  30.626179
# 1           35.368197  25.901566  20.646118  28.343690
# All         38.233441  29.877630  25.140620  29.699118

# %%
pd.crosstab(data['Sobreviveu'], data['Classe'], values = data['Idade'], aggfunc = lambda  x :  x . mean () * 2 )
# Out:
# Classe              1          2          3
# Sobreviveu
# 0           87.390625  67.088889  53.111111
# 1           70.736393  51.803133  41.292235

# %%
pd.crosstab(data['Sobreviveu'], data['Classe'], normalize=True)
# Out:
# Classe             1         2         3
# Sobreviveu
# 0           0.089787  0.108866  0.417508
# 1           0.152637  0.097643  0.133558

# %%
pd.crosstab(data['Sobreviveu'], [data['Classe'], data['Sexo']])
# Out:
# Classe         1            2            3
# Sexo       homem mulher homem mulher homem mulher
# Sobreviveu
# 0             77      3    91      6   300     72
# 1             45     91    17     70    47     72

# %%
pd.crosstab(data['Sobreviveu'], data['Classe'], margins=True).style.background_gradient(cmap='OrRd')
# Out:
# <style type="text/css">
# #T_4a7ba_row0_col0, #T_4a7ba_row1_col1, #T_4a7ba_row1_col2, #T_4a7ba_row1_col3 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_4a7ba_row0_col1 {
#   background-color: #feebcf;
#   color: #000000;
# }
# #T_4a7ba_row0_col2 {
#   background-color: #e44d35;
#   color: #f1f1f1;
# }
# #T_4a7ba_row0_col3 {
#   background-color: #fdba83;
#   color: #000000;
# }
# #T_4a7ba_row1_col0 {
#   background-color: #fdad77;
#   color: #000000;
# }
# #T_4a7ba_row2_col0, #T_4a7ba_row2_col1, #T_4a7ba_row2_col2, #T_4a7ba_row2_col3 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4a7ba_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Classe</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#       <th class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sobreviveu</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a7ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a7ba_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_4a7ba_row0_col1" class="data row0 col1" >97</td>
#       <td id="T_4a7ba_row0_col2" class="data row0 col2" >372</td>
#       <td id="T_4a7ba_row0_col3" class="data row0 col3" >549</td>
#     </tr>
#     <tr>
#       <th id="T_4a7ba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a7ba_row1_col0" class="data row1 col0" >136</td>
#       <td id="T_4a7ba_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_4a7ba_row1_col2" class="data row1 col2" >119</td>
#       <td id="T_4a7ba_row1_col3" class="data row1 col3" >342</td>
#     </tr>
#     <tr>
#       <th id="T_4a7ba_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_4a7ba_row2_col0" class="data row2 col0" >216</td>
#       <td id="T_4a7ba_row2_col1" class="data row2 col1" >184</td>
#       <td id="T_4a7ba_row2_col2" class="data row2 col2" >491</td>
#       <td id="T_4a7ba_row2_col3" class="data row2 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(data['Sobreviveu'], data['Sexo'], margins=True).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_bdd03_row0_col0 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_bdd03_row0_col1, #T_bdd03_row1_col0, #T_bdd03_row1_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bdd03_row0_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_bdd03_row1_col1 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_bdd03_row2_col0, #T_bdd03_row2_col1, #T_bdd03_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bdd03_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Sexo</th>
#       <th class="col_heading level0 col0" >homem</th>
#       <th class="col_heading level0 col1" >mulher</th>
#       <th class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sobreviveu</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdd03_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bdd03_row0_col0" class="data row0 col0" >468</td>
#       <td id="T_bdd03_row0_col1" class="data row0 col1" >81</td>
#       <td id="T_bdd03_row0_col2" class="data row0 col2" >549</td>
#     </tr>
#     <tr>
#       <th id="T_bdd03_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bdd03_row1_col0" class="data row1 col0" >109</td>
#       <td id="T_bdd03_row1_col1" class="data row1 col1" >233</td>
#       <td id="T_bdd03_row1_col2" class="data row1 col2" >342</td>
#     </tr>
#     <tr>
#       <th id="T_bdd03_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_bdd03_row2_col0" class="data row2 col0" >577</td>
#       <td id="T_bdd03_row2_col1" class="data row2 col1" >314</td>
#       <td id="T_bdd03_row2_col2" class="data row2 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
cross = pd.crosstab(data['Sobreviveu'], data['Sexo'], margins=True)
sns.heatmap(cross, cmap='rocket_r', annot=True, fmt='g')
# Out:
# <AxesSubplot:xlabel='Sexo', ylabel='Sobreviveu'>

# %%
data.isna()
# Out:
#      IdPassageiro  Sobreviveu  Classe   Nome   Sexo  Idade  IrmaoConjuge  \
# 0           False       False   False  False  False  False         False
# 1           False       False   False  False  False  False         False
# 2           False       False   False  False  False  False         False
# 3           False       False   False  False  False  False         False
# 4           False       False   False  False  False  False         False
# ..            ...         ...     ...    ...    ...    ...           ...
# 886         False       False   False  False  False  False         False
# 887         False       False   False  False  False  False         False
# 888         False       False   False  False  False   True         False
# 889         False       False   False  False  False  False         False
# 890         False       False   False  False  False  False         False
#
#      PaisFilhos  Bilhete  Tarifa  Cabine  Embarque
# 0         False    False   False    True     False
# 1         False    False   False   False     False
# 2         False    False   False    True     False
# 3         False    False   False   False     False
# 4         False    False   False    True     False
# ..          ...      ...     ...     ...       ...
# 886       False    False   False    True     False
# 887       False    False   False   False     False
# 888       False    False   False    True     False
# 889       False    False   False   False     False
# 890       False    False   False    True     False
#
# [891 rows x 12 columns]

# %%
data['Embarque'].value_counts(dropna = False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarque, dtype: int64

# %%
data.loc[data['Embarque'].isnull()]
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 61             62           1       1
# 829           830           1       1
#
#                                           Nome    Sexo  Idade  IrmaoConjuge  \
# 61                         Icard, Miss. Amelie  mulher   38.0             0
# 829  Stone, Mrs. George Nelson (Martha Evelyn)  mulher   62.0             0
#
#      PaisFilhos Bilhete  Tarifa Cabine Embarque
# 61            0  113572    80.0    B28      NaN
# 829           0  113572    80.0    B28      NaN

# %%
data[data['Embarque'].notnull()].head()
# ~ negação da condição
data[~data['Embarque'].isnull()].head()
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris   homem   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
# 2                             Heikkinen, Miss. Laina  mulher   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher   35.0
# 4                           Allen, Mr. William Henry   homem   35.0
#
#    IrmaoConjuge  PaisFilhos           Bilhete   Tarifa Cabine Embarque
# 0             1           0         A/5 21171   7.2500    NaN        S
# 1             1           0          PC 17599  71.2833    C85        C
# 2             0           0  STON/O2. 3101282   7.9250    NaN        S
# 3             1           0            113803  53.1000   C123        S
# 4             0           0            373450   8.0500    NaN        S

# %%
data[data['Embarque'].notnull()].head()
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris   homem   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
# 2                             Heikkinen, Miss. Laina  mulher   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher   35.0
# 4                           Allen, Mr. William Henry   homem   35.0
#
#    IrmaoConjuge  PaisFilhos           Bilhete   Tarifa Cabine Embarque
# 0             1           0         A/5 21171   7.2500    NaN        S
# 1             1           0          PC 17599  71.2833    C85        C
# 2             0           0  STON/O2. 3101282   7.9250    NaN        S
# 3             1           0            113803  53.1000   C123        S
# 4             0           0            373450   8.0500    NaN        S

# %%
data.describe(include='O')
# Out:
#                            Nome   Sexo Bilhete   Cabine Embarque
# count                       891    891     891      204      889
# unique                      891      2     681      147        3
# top     Braund, Mr. Owen Harris  homem  347082  B96 B98        S
# freq                          1    577       7        4      644

# %%
data.isnull().sum()
# Out:
# 2

# %%
print(data['Embarque'].unique())
print(data['Embarque'].mode())
# Out:
# ['S' 'C' 'Q' nan]
# 0    S
# dtype: object

# %%
data['Embarque'].mode()[0]
# Out:
# 'S'

# %%
data.isna().sum()
# Out:
# IdPassageiro      0
# Sobreviveu        0
# Classe            0
# Nome              0
# Sexo              0
# Idade           177
# IrmaoConjuge      0
# PaisFilhos        0
# Bilhete           0
# Tarifa            0
# Cabine          687
# Embarque          2
# dtype: int64

# %%
data['Embarque'] = data['Embarque'].fillna('S')

# %%
moda = data['Embarque'].mode()[0]
data.loc[:,'Embarque'] = data['Embarque'].fillna(media)

# %%
data['Embarque'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
data.isna().sum()
# Out:
# IdPassageiro    0
# Sobreviveu      0
# Classe          0
# Nome            0
# Sexo            0
# Idade           0
# IrmaoConjuge    0
# PaisFilhos      0
# Bilhete         0
# Tarifa          0
# Embarque        0
# dtype: int64

# %%
data['Embarque'].at[61] = 'Q'
data.iloc[61]
# Out:
# IdPassageiro                      81
# Sobreviveu                         0
# Classe                             3
# Nome            Waelens, Mr. Achille
# Sexo                           homem
# Idade                           22.0
# IrmaoConjuge                       0
# PaisFilhos                         0
# Bilhete                       345767
# Tarifa                           9.0
# Embarque                           S
# Name: 80, dtype: object

# %%
data.iat[61, 11] = 'S'
data.iloc[61]
# Out:
# IdPassageiro                     62
# Sobreviveu                        1
# Classe                            1
# Nome            Icard, Miss. Amelie
# Sexo                         mulher
# Idade                          38.0
# IrmaoConjuge                      0
# PaisFilhos                        0
# Bilhete                      113572
# Tarifa                         80.0
# Cabine                          B28
# Embarque                          S
# Name: 61, dtype: object

# %%
data.iloc[61]
# Out:
# IdPassageiro                     62
# Sobreviveu                        1
# Classe                            1
# Nome            Icard, Miss. Amelie
# Sexo                         mulher
# Idade                          38.0
# IrmaoConjuge                      0
# PaisFilhos                        0
# Bilhete                      113572
# Tarifa                         80.0
# Cabine                          B28
# Embarque                          S
# Name: 61, dtype: object

# %%
data.columns
# Out:
# Index(['IdPassageiro', 'Sobreviveu', 'Classe', 'Nome', 'Sexo', 'Idade',
#        'IrmaoConjuge', 'PaisFilhos', 'Bilhete', 'Tarifa', 'Cabine',
#        'Embarque'],
#       dtype='object')

# %%
data.iloc[[61,829]]
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 61             62           1       1
# 829           830           1       1
#
#                                           Nome    Sexo  Idade  IrmaoConjuge  \
# 61                         Icard, Miss. Amelie  mulher   38.0             0
# 829  Stone, Mrs. George Nelson (Martha Evelyn)  mulher   62.0             0
#
#      PaisFilhos Bilhete  Tarifa Cabine Embarque
# 61            0  113572    80.0    B28      NaN
# 829           0  113572    80.0    B28      NaN

# %%
data.dropna(axis=1, thresh=600, inplace=True)
data.head()
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris   homem   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
# 2                             Heikkinen, Miss. Laina  mulher   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher   35.0
# 4                           Allen, Mr. William Henry   homem   35.0
#
#    IrmaoConjuge  PaisFilhos           Bilhete   Tarifa Embarque
# 0             1           0         A/5 21171   7.2500        S
# 1             1           0          PC 17599  71.2833        C
# 2             0           0  STON/O2. 3101282   7.9250        S
# 3             1           0            113803  53.1000        S
# 4             0           0            373450   8.0500        S

# %%
data.dropna(axis=0, subset=['Idade'], inplace=True)

# %%
data.shape
# Out:
# (714, 11)

# %%
data[data['Bilhete'].isin(['PC 17599'])]
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 1             2           1       1
#
#                                                 Nome    Sexo  Idade  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
#
#    IrmaoConjuge  PaisFilhos   Bilhete   Tarifa Cabine Embarque
# 1             1           0  PC 17599  71.2833    C85        C
