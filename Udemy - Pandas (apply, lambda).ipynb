# %%
import pandas as pd
import numpy as np 
data = pd.read_csv('titanic/train.csv') # Comma Separated Values - Valores Separados Por Vírgula
data.columns = ['IdPassageiro', 'Sobreviveu', 'Classe', 'Nome', 'Sexo', 'Idade', 
                'IrmaoConjuge', 'PaisFilhos', 'Bilhete', 'Tarifa', 'Cabine', 'Embarque']
data['Sexo'].replace({'male': 'homem', 'female': 'mulher'}, inplace=True)
data.head()
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris   homem   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
# 2                             Heikkinen, Miss. Laina  mulher   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher   35.0
# 4                           Allen, Mr. William Henry   homem   35.0
#
#    IrmaoConjuge  PaisFilhos           Bilhete   Tarifa Cabine Embarque
# 0             1           0         A/5 21171   7.2500    NaN        S
# 1             1           0          PC 17599  71.2833    C85        C
# 2             0           0  STON/O2. 3101282   7.9250    NaN        S
# ...

# %%
data.apply(lambda x: (x+10)  if x.name == 'Classe' else x)

# %%
df = pd.DataFrame({'X': [1, 2, 3,],
                   'Y': [4, 1, 8]})
print("Original DataFrame")
print(df)
modified_df=df.apply(lambda x: (x*2)  if x.name == 'X' else x)
print("Modified DataFrame")
print(modified_df)

# %%
data['Bilhete'].sort_values()

# %%
x = '110413'

# %%
x[:-1]

# %%
data['Bilhete'] = data['Bilhete'].apply(lambda x: x + 'A').sort_values()

# %%
def soma(*args):
    return sum(args)

data['Tarifa'].apply(soma, args=(2,5))

# %%
data.apply(lambda x: 'Tarifa' if x.Tarifa > x.Idade else 'Idade', axis=1)

# %%
data['Classe'] = data['Classe'].apply(lambda x: 5 if x== 2 else x)
data['Classe'].unique()

# %%
data['Classe'].value_counts()

# %%
def calculate_area(row):
    return row.sum()

data = {
  "x": [50, 40, 30],
  "y": [300, 1112, 42]
}

df = pd.DataFrame(data)

x = df.apply(lambda x: x.sum() if x.name == 'Classe' else x)

print(x)

# %%
data['Somatória'] = data['Tarifa']
data = data.apply(lambda x: x.sum() if x.name == 'Somatória' else x)
data

# %%
def calculate_area(row):
    if row['x']:
        return row['x'] * row['y']

data = {
  "x": [50, 40, 30],
  "y": [300, 1112, 42]
}

df = pd.DataFrame(data)

x = df.apply(lambda x , axis=1)

print(x)

# %%
data.apply(lambda x: 'Tarifa' if x.Tarifa > x.Idade else 'Idade', axis=1)

# %%
data['Tarifa'].apply(np.square, raw=False)

# %%
data.apply(lambda x: 'Tarifa' if x.Tarifa > x.Idade else 'Idade', axis=1)

# %%
data['Classe'].unique()

# %%
data.apply(lambda x: 'Tarifa' if x.Tarifa > x.Idade else 'Idade', axis=1, result_type='broadcast')

# %%
data.apply(lambda x: x.Tarifa, axis=1, result_type='expand')

# %%
pd.get_dummies(data, columns=['Sexo'], prefix="Column")

# %%
from category_encoders.one_hot import OneHotEncoder

# criação do df com os dados categoricos
df_cats = data.select_dtypes(include='object') 
one_hot = OneHotEncoder(cols=['Sexo'])
one_hot.fit_transform(df_cats)

# %%
data['Nome'].str.extract('\w')

# %%
for indice, linha in data.iterrows():
    print(f'Indice: {indice}')
    print(f'linha: \n{linha}')
    break
# Out:
# Indice: 0
# linha:
# IdPassageiro                          1
# Sobreviveu                            0
# Classe                                3
# Nome            Braund, Mr. Owen Harris
# Sexo                              homem
# Idade                              22.0
# IrmaoConjuge                          1
# PaisFilhos                            0
# Bilhete                       A/5 21171
# Tarifa                             7.25
# Cabine                              NaN
# Embarque                              S
# Classe Nova                 Classe alta
# Name: 0, dtype: object

# %%
for i in data.iterrows():
    print(f'Linha: {i[0]}')
    print(f'Colunas: \n{i[1]}')
    break
# Out:
# Linha: 0
# Colunas:
# IdPassageiro                          1
# Sobreviveu                            0
# Classe                                3
# Nome            Braund, Mr. Owen Harris
# Sexo                              homem
# Idade                              22.0
# IrmaoConjuge                          1
# PaisFilhos                            0
# Bilhete                       A/5 21171
# Tarifa                             7.25
# Cabine                              NaN
# Embarque                              S
# Name: 0, dtype: object

# %%
print(f'Linha: {i[0]}')
valores = []print(f'Colunas: \n{i[1]}')
# Out:
# Linha: 0
# Colunas:
# IdPassageiro                          1
# Sobreviveu                            0
# Classe                                3
# Nome            Braund, Mr. Owen Harris
# Sexo                              homem
# Idade                              22.0
# IrmaoConjuge                          1
# PaisFilhos                            0
# Bilhete                       A/5 21171
# Tarifa                             7.25
# Cabine                              NaN
# Embarque                              S
# Name: 0, dtype: object

# %%
# %%timeit -r1
classe = []
for indice, linha in data.iterrows():
    classe.append('Classe alta' if linha['Classe'] ==3 else 'Classe')
data['Classe Nova'] = classe
data
# Out:
# 49.4 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 10 loops each)

# %%
# %%timeit -r1
classe = []
for linha in data.itertuples():
    classe.append('Classe alta' if linha.Classe ==3 else 'Classe')
data['Classe Nova'] = classe
data
# Out:
# 3.22 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 100 loops each)

# %%
classe = []
for indice, linha in data.iteritems():
    print(indice)
    print(linha)
    break
# Out:
# IdPassageiro
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: IdPassageiro, Length: 891, dtype: int64

# %%
for i in data.iterrows():
    print(f'Linha: {i[0]}')
    print(f'Colunas: \n{i[1]}')
# Out:
# Linha: 0
# Colunas:
# IdPassageiro                          1
# Sobreviveu                            0
# Classe                                3
# Nome            Braund, Mr. Owen Harris
# Sexo                              homem
# Idade                              22.0
# IrmaoConjuge                          1
# PaisFilhos                            0
# Bilhete                       A/5 21171
# Tarifa                             7.25
# Cabine                              NaN
# Embarque                              S
# Classe Nova                 Classe alta
# Name: 0, dtype: object
# Linha: 1
# Colunas:
# IdPassageiro                                                    2
# Sobreviveu                                                      1
# Classe                                                          1
# Nome            Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sexo                                                       mulher
# ...

# %%
for coluna in data.columns:
    data[coluna]

# %%
for coluna, valor in data.iteritems():
    print(valor[2])
    break
coluna, valor
# Out:
# 3
# ('IdPassageiro',
#  0        1
#  1        2
#  2        3
#  3        4
#  4        5
#        ...
#  886    887
#  887    888
#  888    889
#  889    890
#  890    891
#  Name: IdPassageiro, Length: 891, dtype: int64)

# %%
for nome, valores in data.iteritems():
    break
nome, valores
# Out:
# ('IdPassageiro',
#  0        1
#  1        2
#  2        3
#  3        4
#  4        5
#        ...
#  886    887
#  887    888
#  888    889
#  889    890
#  890    891
#  Name: IdPassageiro, Length: 891, dtype: int64)

# %%
moda = {}
for nome, valores in data.iteritems():
    moda[nome] = valores.mode()[0]
moda
# Out:
# {'IdPassageiro': 1,
#  'Sobreviveu': 0,
#  'Classe': 3,
#  'Nome': 'Abbing, Mr. Anthony',
#  'Sexo': 'homem',
#  'Idade': 24.0,
#  'IrmaoConjuge': 0,
#  'PaisFilhos': 0,
#  'Bilhete': '1601',
#  'Tarifa': 8.05,
#  'Cabine': 'B96 B98',
#  'Embarque': 'S',
#  'Classe Nova': 'Classe alta'}

# %%
classe = []
for nome, valores in data.iteritems():
    print(f'nome: {nome}')
    print(f' valor: {valores[0]}')
    print('Classe alta' if valores[0] ==3 else 'Classe')
# Out:
# nome: IdPassageiro
#  valor: 1
# Classe
# nome: Sobreviveu
#  valor: 0
# Classe
# nome: Classe
#  valor: 3
# Classe alta
# nome: Nome
#  valor: Braund, Mr. Owen Harris
# Classe
# nome: Sexo
#  valor: homem
# Classe
# nome: Idade
#  valor: 22.0
# Classe
# nome: IrmaoConjuge
#  valor: 1
# Classe
# nome: PaisFilhos
#  valor: 0
# Classe
# nome: Bilhete
#  valor: A/5 21171
# Classe
# nome: Tarifa
#  valor: 7.25
# Classe
# nome: Cabine
#  valor: nan
# Classe
# nome: Embarque
#  valor: S
# Classe
# nome: Classe Nova
#  valor: Classe alta
# Classe
